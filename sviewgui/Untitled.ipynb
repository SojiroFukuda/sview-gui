# %%
import sview as sv
import seaborn as sns
df = sns.load_dataset("penguins")

# sv.buildGUI('/Users/fukudasoujirou/Documents/Hull_Uni/Program/Python/Other/Hannah/FPS_PCA.csv')
sv.buildGUI(df)

# %%
from sviewgui import sview as sv

sv.buildGUI('/Users/fukudasoujirou/Documents/Hull_Uni/Program/Python/Other/Hannah/FPS_PCA.csv')

# %%
import matplotlib
import matplotlib.colors as mcolors
import matplotlib.markers as mmarkers
from matplotlib.lines import Line2D
import seaborn as sns
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

    
def diagnose(array):
    def isfloat(s):
        try:
            float(s)
        except ValueError:
            return False
        else:
            return True
    def isnan(s):
        try:
            np.isnan(s)
        except TypeError:
            return False
        else:
            return np.isnan(s)
    float_ind = [ isfloat(var) for var in array] # booleans if a value is compativle with float
    num_str = len(float_ind) - np.sum(float_ind) # Number of non-float values (mostly string)
    float_array = [float(var) for var in [array[ind] for ind,val in enumerate(float_ind) if val == True] ] # float_compatibl
    nan_ind = [isnan(var) for var in float_array] # 
    num_nan = np.sum(nan_ind) # Number of NaN
    nan_safe_array = [float(float_array[ind]) for ind,val in enumerate(nan_ind) if val == False]
    inf_ind = [np.isinf(var) for var in nan_safe_array]
    num_inf = np.sum(inf_ind)
    inf_safe_array = [float(nan_safe_array[ind]) for ind,val in enumerate(inf_ind) if val == False]
    return {'Total':len(array),'Numeric':len(inf_safe_array) ,'String':num_str,'NaN':num_nan,'Inf':num_inf}
    
array = np.array(['a',1,2,3,4,'b',5,np.nan,-np.inf,4.0,np.inf])
print(diagnose(array))

# %%
#This code is automatically generated by SView
#Based on matplotlib and seaborn
#========================
# package ----
import numpy as np
import pandas as pd
from matplotlib import style
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.lines import Line2D
import seaborn as sns
import cmocean
# ------------- 
#2022/05/22 00:34:36 
#- DataFrame ---------- 
DATA = sns.load_dataset("penguins")

#- Axes Setting ---------- 
fig, ax = plt.subplots()
ax.set_xlabel( "bill_length_mm")
ax.set_ylabel( "bill_depth_mm" )
ax.set_xlim(min(DATA['bill_length_mm'].replace([np.inf, -np.inf], np.nan ).dropna() ) - abs( min(DATA['bill_length_mm'].replace([np.inf, -np.inf], np.nan ).dropna() )/10), max(DATA['bill_length_mm'].replace([np.inf, -np.inf], np.nan).dropna()) + abs(max(DATA['bill_length_mm'].replace([np.inf, -np.inf], np.nan).dropna())/10)  )
ax.set_ylim( min(DATA['bill_depth_mm'].replace([np.inf, -np.inf], np.nan ).dropna() ) - abs( min(DATA['bill_depth_mm'].replace([np.inf, -np.inf], np.nan ).dropna() )/10), max(DATA['bill_depth_mm'].replace([np.inf, -np.inf], np.nan).dropna()) + abs(max(DATA['bill_depth_mm'].replace([np.inf, -np.inf], np.nan).dropna())/10)  )
#- PLOT ------------------ 
def lighten_color(color, amount=0.5):
    import colorsys
    try:
        c = mcolors.cnames[color]
    except:
        c = color
    c = colorsys.rgb_to_hls(*mcolors.to_rgb(c))
    return colorsys.hls_to_rgb(c[0], 1 - amount * (1 - c[1]), c[2])

newpalette = [lighten_color(var,1.0) for var in plt.rcParams['axes.prop_cycle'].by_key()['color']]
sns.scatterplot(data=DATA.replace([np.inf, -np.inf], np.nan), x ="bill_length_mm", y ="bill_depth_mm", hue = "species", alpha=1.0, palette=newpalette[0:len(pd.unique(DATA["species"]))], ax=ax)
sns.kdeplot(data=DATA, x = "bill_length_mm", y = "bill_depth_mm", hue = "species",legend=False, ax = ax)
plt.show()
plt.close() 
#2022/05/22 00:34:47 
#- DataFrame ---------- 
DATA = sns.load_dataset("penguins") 

#- Axes Setting ---------- 
fig, ax = plt.subplots()
ax.set_xlabel( "bill_length_mm")
ax.set_ylabel( "bill_depth_mm" )
ax.set_xlim(min(DATA['bill_length_mm'].replace([np.inf, -np.inf], np.nan ).dropna() ) - abs( min(DATA['bill_length_mm'].replace([np.inf, -np.inf], np.nan ).dropna() )/10), max(DATA['bill_length_mm'].replace([np.inf, -np.inf], np.nan).dropna()) + abs(max(DATA['bill_length_mm'].replace([np.inf, -np.inf], np.nan).dropna())/10)  )
ax.set_ylim( min(DATA['bill_depth_mm'].replace([np.inf, -np.inf], np.nan ).dropna() ) - abs( min(DATA['bill_depth_mm'].replace([np.inf, -np.inf], np.nan ).dropna() )/10), max(DATA['bill_depth_mm'].replace([np.inf, -np.inf], np.nan).dropna()) + abs(max(DATA['bill_depth_mm'].replace([np.inf, -np.inf], np.nan).dropna())/10)  )
#- PLOT ------------------ 
def lighten_color(color, amount=0.5):
    import colorsys
    try:
        c = mcolors.cnames[color]
    except:
        c = color
    c = colorsys.rgb_to_hls(*mcolors.to_rgb(c))
    return colorsys.hls_to_rgb(c[0], 1 - amount * (1 - c[1]), c[2])

newpalette = [lighten_color(var,0.5000000000000001) for var in plt.rcParams['axes.prop_cycle'].by_key()['color']]
sns.scatterplot(data=DATA.replace([np.inf, -np.inf], np.nan), x ="bill_length_mm", y ="bill_depth_mm", hue = "species", alpha=0.5000000000000001, palette=newpalette[0:len(pd.unique(DATA["species"]))], ax=ax)
sns.kdeplot(data=DATA, x = "bill_length_mm", y = "bill_depth_mm", hue = "species",legend=False, ax = ax)
plt.show()
plt.close()

# %%
#This code is automatically generated by SView
#Based on matplotlib and seaborn
#========================
# package ----
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.lines import Line2D
import seaborn as sns
import cmocean
from matplotlib import style
print(style.available)
style.use('dark_background')
# ------------- 
#2022/05/21 03:38:03 
#- Import CSV as DataFrame ---------- 
FILE_PATH = '/Users/fukudasoujirou/Documents/Hull_Uni/Program/Python/Other/Hannah/FPS_PCA.csv'
DATA = pd.read_csv(FILE_PATH)
#- Axes Setting ---------- 
fig, ax = plt.subplots()
print(ax.xaxis.label.get_color())
def isLightOrDark(rgbColor=[0,128,255]):
    [r,g,b]=rgbColor
    hsp = np.sqrt(0.299 * (r * r) + 0.587 * (g * g) + 0.114 * (b * b))
    if (hsp>100):
        return 'light'
    else:
        return 'dark'
def rgb2gray(rgb):
    r, g, b = rgb[0], rgb[1], rgb[2]
    gray = 0.2989 * r + 0.5870 * g + 0.1140 * b
    return gray
color=ax.xaxis.label.get_color()
# color='white'
rgb = np.array( mcolors.to_rgb( mcolors.to_hex( ax.xaxis.label.get_color() ) ) )*255
# rgb = [140,140,140]
if self.rgb2gray( np.array( mcolors.to_rgb( mcolors.to_hex( ax.xaxis.label.get_color() ) ) )*255 ) < 160:
            self.fig.patch.set_facecolor('#FAEBD7')
        else:
            self.fig.patch.set_facecolor('black')
print(rgb)
print(isLightOrDark(rgbColor=rgb))
print(rgb2gray(rgb))



# print(invert(ax.xaxis.label.get_color()))
ax.set_xlabel( "Area(mm)")
ax.set_ylabel( "Frequency" )
test = np.linspace(-10,10,1000)
y = test
z = test
linthresh=min(abs(test))
clb=plt.colorbar(ax.scatter(test,y,c=z,cmap = cmocean.cm.thermal,norm=mcolors.SymLogNorm(linthresh,vmin=min(z),vmax=max(z))),ax=ax)
ax.set_yscale('symlog',linthresh=linthresh)
# ax.set_xlim(min(DATA['Area(mm)'].replace([np.inf, -np.inf], np.nan ).dropna() ) - abs( min(DATA['Area(mm)'].replace([np.inf, -np.inf], np.nan ).dropna() )/10), max(DATA['Area(mm)'].replace([np.inf, -np.inf], np.nan).dropna()) + abs(max(DATA['Area(mm)'].replace([np.inf, -np.inf], np.nan).dropna())/10)  )
#- PLOT ------------------ 
# sns.histplot(D_ATA.replace([np.inf, -np.inf], np.nan).dropna(),x='Area(mm)',hue='Facies',stat='probability', bins = 10, log_scale=True, element='step',legend=False ,ax = ax)
plt.show()
plt.close()

# %%
from matplotlib import style
from matplotlib import pyplot as plt
print(style.available)
style.use('ggplot')
print(plt.rcParams['axes.prop_cycle'].by_key()['color'] )
